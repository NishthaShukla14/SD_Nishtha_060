# %% [markdown]
# <a href="https://colab.research.google.com/github/NishthaShukla14/SD_Nishtha_060/blob/main/ATM_card.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hey,Welcome to our ATM")
balance=5000
pin=1909
p=int(input("Enter the PIN"))
if p==pin:
  amount=int(input("Enter the amount to be withdrawl"))
  balance=balance-amount
  print("Your balance is",balance)
else:
  print("Invalid PIN")
# Out:
# Hey,Welcome to our ATM
# Enter the PIN1909
# Enter the amount to be withdrawl2000
# Your balance is 3000
