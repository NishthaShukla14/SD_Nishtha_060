# %% [markdown]
# <a href="https://colab.research.google.com/github/NishthaShukla14/SD_Nishtha_060/blob/main/OOPs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=1
print(type(a))
# Out:
# <class 'int'>

# %%
print(type("skills"))
# Out:
# <class 'str'>

# %%
class test :
  pass

# %%
class skills:
  def welcome_msg(self):
    print("welcome to skills")

# %%
rohan = skills()

# %%
print(type(rohan))
# Out:
# <class '__main__.skills'>

# %%
print(type(rohan))
# Out:
# <class '__main__.skills'>

# %%
rohan.welcome_msg()
# Out:
# welcome to skills

# %%
gaurav = skills()

# %%
gaurav.welcome_msg()
# Out:
# welcome to skills

# %%
class skills1:
  def __init__(self,phone_number,email_id,student_id):
    self.phone_number = phone_number
    self.email_id = email_id
    self.student_id = student_id
  def return_student_deetails(self):
    return self.phone_number,self.email_id,self.student_id

# %%
rohan = skills1(1234567890, "rohan@example.com", "S123")
print(rohan.email_id)

# similar to any name
# Out:
# rohan@example.com

# %%
class skills2:
  def __init__(self,phone_number,email_id,student_id):
    self.phone_number1 = phone_number
    self.email_id1 = email_id
    self.student_id1 = student_id
  def return_student_deetails(self):
   return self.phone_number1,self.email_id1,self.student_id1
