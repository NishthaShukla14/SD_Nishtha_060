# %% [markdown]
# <a href="https://colab.research.google.com/github/NishthaShukla14/SD_Nishtha_060/blob/main/NUMPY_AND_PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
l=[1,2,3,4]

# %%
ar= np.array(l)

# %%
ar
# Out:
# array([1, 2, 3, 4])

# %%
type(ar)
# Out:
# numpy.ndarray

# %%
np.array([[1,2],[3,4]])
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.asarray(l)
# Out:
# array([1, 2, 3, 4])

# %%
a=[2,3,4]

# %%
import numpy as np
a = [2,3,4]
np.asanyarray(a)
# Out:
# array([2, 3, 4])

# %%
b = []
b
# Out:
# []

# %% [markdown]
# PANDAS

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/weather.csv')

# %%
df.loc[0:5,['MinTemp','MaxTemp','Rainfall']]
# Out:
#    MinTemp  MaxTemp  Rainfall
# 0      8.0     24.3       0.0
# 1     14.0     26.9       3.6
# 2     13.7     23.4       3.6
# 3     13.3     15.5      39.8
# 4      7.6     16.1       2.8
# 5      6.2     16.9       0.0

# %%
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.sample(5)
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 219     -0.2     15.5       0.0          1.4       9.0          NE
# 212     -0.9     18.5       0.0          2.2       8.9           E
# 57      15.1     28.3      14.4          8.8      13.2         NNW
# 336      5.6     27.6       0.0          5.2      11.0          NW
# 342      0.5     17.9       0.0          5.8      11.5           N
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 219           28.0          N        ESE           4.0  ...           42
# 212           22.0        NaN          N           0.0  ...           38
# 57            28.0        NNW         NW           6.0  ...           44
# 336           46.0        NNW         NW          15.0  ...           21
# 342           44.0        NNE        NNW           2.0  ...           33
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
df.shape
# Out:
# (366, 22)

# %%
df["MinTemp"]
# Out:
# 0       8.0
# 1      14.0
# 2      13.7
# 3      13.3
# 4       7.6
#        ...
# 361     9.0
# 362     7.1
# 363    12.5
# 364    12.5
# 365    12.3
# Name: MinTemp, Length: 366, dtype: float64

# %%
df["MaxTemp"]
# Out:
# 0      24.3
# 1      26.9
# 2      23.4
# 3      15.5
# 4      16.1
#        ...
# 361    30.7
# 362    28.4
# 363    19.9
# 364    26.9
# 365    30.2
# Name: MaxTemp, Length: 366, dtype: float64

# %%
df["Rainfall"]
# Out:
# 0       0.0
# 1       3.6
# 2       3.6
# 3      39.8
# 4       2.8
#        ...
# 361     0.0
# 362     0.0
# 363     0.0
# 364     0.0
# 365     0.0
# Name: Rainfall, Length: 366, dtype: float64

# %%
df.iloc[0]
# Out:
# MinTemp             8.0
# MaxTemp            24.3
# Rainfall            0.0
# Evaporation         3.4
# Sunshine            6.3
# WindGustDir          NW
# WindGustSpeed      30.0
# WindDir9am           SW
# WindDir3pm           NW
# WindSpeed9am        6.0
# WindSpeed3pm         20
# Humidity9am          68
# Humidity3pm          29
# Pressure9am      1019.7
# Pressure3pm      1015.0
# Cloud9am              7
# Cloud3pm              7
# Temp9am            14.4
# Temp3pm            23.6
# RainToday            No
# RISK_MM             3.6
# RainTomorrow        Yes
# Name: 0, dtype: object

# %%
df.iloc[2]
# Out:
# MinTemp            13.7
# MaxTemp            23.4
# Rainfall            3.6
# Evaporation         5.8
# Sunshine            3.3
# WindGustDir          NW
# WindGustSpeed      85.0
# WindDir9am            N
# WindDir3pm          NNE
# WindSpeed9am        6.0
# WindSpeed3pm          6
# Humidity9am          82
# Humidity3pm          69
# Pressure9am      1009.5
# Pressure3pm      1007.2
# Cloud9am              8
# Cloud3pm              7
# Temp9am            15.4
# Temp3pm            20.2
# RainToday           Yes
# RISK_MM            39.8
# RainTomorrow        Yes
# Name: 2, dtype: object

# %%
df.iloc[0:10]
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
# 5      6.2     16.9       0.0          5.8       8.2          SE
# 6      6.1     18.2       0.2          4.2       8.4          SE
# 7      8.3     17.0       0.0          5.6       4.6           E
# 8      8.8     19.5       0.0          4.0       4.1           S
# 9      8.4     22.8      16.2          5.4       7.7           E
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# ...

# %%
df.iloc[4:7]
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 4      7.6     16.1       2.8          5.6      10.6         SSE
# 5      6.2     16.9       0.0          5.8       8.2          SE
# 6      6.1     18.2       0.2          4.2       8.4          SE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 4           50.0        SSE        ESE          20.0  ...           49
# 5           44.0         SE          E          20.0  ...           57
# 6           43.0         SE        ESE          19.0  ...           47
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 4       1018.3       1018.5         7         7     11.1     15.4        Yes
# 5       1023.8       1021.7         7         5     10.9     14.8         No
# 6       1024.6       1022.2         4         6     12.4     17.3         No
#
#    RISK_MM RainTomorrow
# 4      0.0           No
# 5      0.2           No
# 6      0.0           No
#
# ...

# %%
df.iloc[:,0:5]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine
# 0        8.0     24.3       0.0          3.4       6.3
# 1       14.0     26.9       3.6          4.4       9.7
# 2       13.7     23.4       3.6          5.8       3.3
# 3       13.3     15.5      39.8          7.2       9.1
# 4        7.6     16.1       2.8          5.6      10.6
# ..       ...      ...       ...          ...       ...
# 361      9.0     30.7       0.0          7.6      12.1
# 362      7.1     28.4       0.0         11.6      12.7
# 363     12.5     19.9       0.0          8.4       5.3
# 364     12.5     26.9       0.0          5.0       7.1
# 365     12.3     30.2       0.0          6.0      12.6
#
# [366 rows x 5 columns]

# %%
df[df["MaxTemp"]>30]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 13      12.1     30.9       0.0          6.2      12.4          NW
# 14      10.1     31.2       0.0          8.8      13.1          NW
# 15      12.4     32.1       0.0          8.4      11.1           E
# 16      13.8     31.2       0.0          7.2       8.4         ESE
# 18      12.4     32.3       0.6          7.4      13.0           E
# 19      15.6     33.4       0.0          8.0      10.4          NE
# 20      15.3     33.4       0.0          8.8       9.5         WNW
# 58      14.4     31.6       0.0          6.6      13.6         NNW
# 59      15.4     35.0       0.0          9.6      13.0           E
# 60      13.8     33.5       0.0         11.4      13.6          NE
# 61      13.6     34.2       0.0          8.8      12.8         NNE
# 62      14.3     35.0       0.0          7.6      10.5         ESE
# 66      14.3     34.1       0.0          6.6      10.5         ENE
# ...

# %%
df[df["MaxTemp"]<30]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 359      3.3     25.5       0.0          5.2      10.8           N
# 360      7.9     26.1       0.0          6.8       3.5         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
plt.figure(figsize=(8,5))
plt.hist(df["MaxTemp"], bins=20)
plt.title("Distribution of Median House Values")
plt.xlabel("Median House Value")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()
