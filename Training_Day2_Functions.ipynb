# %% [markdown]
# <a href="https://colab.research.google.com/github/NishthaShukla14/SD_Nishtha_060/blob/main/Training_Day2_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(
  a = 10,
  b = 4):
  return a+b

# %%
def test():
  pass

# %%
def test1():
  print("this is my very very first function")

# %%
test1()
# Out:
# this is my very very first function

# %%
def test3():
  return "sudh ",23,345.56,[1,2,3,3]

# %%
test3()
# Out:
# ('sudh ', 23, 345.56, [1, 2, 3, 3])

# %%
a,b,c,d =test3()

# %%
a
# Out:
# 'sudh '

# %%
b
# Out:
# 23

# %%
c
# Out:
# 345.56

# %%
d
# Out:
# [1, 2, 3, 3]

# %%
def test4():
  a=5+6/7
  return a

# %%
test4()
# Out:
# 5.857142857142857

# %%
def test5(a,b,c):
  d=a+b/c
  return d

# %%
test5(1, 2, 3)
# Out:
# 1.6666666666666665

# %%
def test6(a,b):
    return a+b

# %%
test6(5.0, 9.8)
# Out:
# 14.8

# %%
test6(3,4)
# Out:
# 7

# %%
l =[1,2,3,4,"sudh","kumar",[1,2,3,4,5,6]]

# %%
l1 =[]
for i in l:
  if type(i) == int or type(i) == list:
    l1.append(i)

# %%
l1
# Out:
# [1, 2, 3, 4, [1, 2, 3, 4, 5, 6]]

# %%
def test8(a):
  l=[]
  for i in a:
    if type(i) == list:
      for j in i:
        l.append(j)
    else:
      if type(i) == int or type(i) == float:
        l.append(i)
  return l

# %%
test8(l)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4, 5, 6]
